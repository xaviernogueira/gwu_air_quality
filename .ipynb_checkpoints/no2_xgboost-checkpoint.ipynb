# %%
import xgboost as xgb
import sklearn
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib as mpl
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import ipympl
import seaborn as sns
import useful_functions
import scipy
from scipy.stats import gaussian_kde
print('Using xgboost version %s' % xgb.__version__)
print('Using scikit-learn version %s' % sklearn.__version__)
# %matplotlib widget
# Out:
# Using xgboost version 1.4.2
# Using scikit-learn version 1.0

# %% [markdown]
# ### Prep data and choose input variables

# %%
# import data, remove non-necessary columns
DATA_LOCATION = r'C:\Users\xrnogueira\Documents\Data\NO2_stations\master_no2_daily_test_500_rows.csv'
in_data = pd.read_csv(DATA_LOCATION)
keep_cols = ['mean_no2', 'weekend', 'sp', 'swvl1', 't2m', 'tp', 'u10', 'v10', 'blh', 'u100', 'v100', 'p_roads_1000', 's_roads_1700', 's_roads_3000', 'tropomi', 'pod_den_1100', 'Z_r',]
in_data = in_data[keep_cols]


# standardize column headers
for col in list(in_data.columns):
        if in_data[col].dtypes == object:
            in_data[col].replace(' ', '_', regex=True, inplace=True)
        if ' ' in str(col)[:-1]:
            new = str(col).replace(' ', '_')
            if new[-1] == '_':
                new = new[:-1]
            in_data.rename(columns={str(col): new}, inplace=True)
        
            
in_data.head()
# Out:
#     mean_no2  weekend           sp     swvl1         t2m        tp       u10  \
# 0  33.291667        0  86911.01557  0.405454  269.739805  0.002423 -1.080268
# 1   8.686957        0  99059.12038  0.324161  267.119291  0.001630  1.778470
# 2   4.715789        0  83312.93520  0.395461  269.165219  0.000286 -0.396269
# 3   4.666667        0  97988.29041  0.466480  271.870177  0.005791  1.274388
# 4  18.681818        1  98059.90825  0.187030  288.631371  0.004175 -0.139594
#
#         v10          blh      u100      v100  p_roads_1000  s_roads_1700  \
# 0  0.661982   114.434598 -0.728227  1.286281      6.050956      4.945142
# 1 -1.075310   447.432957  0.198183  0.041495      4.169124      6.045182
# 2  0.784059  1116.898926 -0.194601  1.562163      0.000000      3.294103
# 3  0.326976   519.989826  0.894252  1.814834      8.144184      0.519936
# 4  0.102949   254.542703  0.575536  0.183747      7.960621      2.645854
#
#    s_roads_3000       tropomi  pod_den_1100  Z_r
# 0     12.756178  1.410000e+16   3859.171798  0.0
# 1     43.158852  2.582650e+15   8356.886382  0.0
# 2      9.029836  1.372230e+15   2669.920134  0.0
# 3      2.320980  2.442060e+15   2497.753292  0.0
# 4      9.867187  2.769600e+15   3943.426583  0.0

# %%
# make a separate dataframe formatted for Seaborn plotting
# %matplotlib widget
cont_df = in_data.drop('weekend', axis=1)
cols = list(cont_df.columns)
print(cols)
dfs = []
for i, val in enumerate(cols):
    sub_df = pd.DataFrame()
    sub_df['value'] = in_data[[val]]
    sub_df['std_val'] = (sub_df - sub_df.mean())/sub_df.std()
    sub_df['key'] = val
    dfs.append(sub_df)
    
plot_df = pd.concat(dfs)
print('Continous variables: %s' % plot_df.key.unique())

sns.boxenplot(x="std_val", y="key", data=plot_df)
# Out:
# ['mean_no2', 'sp', 'swvl1', 't2m', 'tp', 'u10', 'v10', 'blh', 'u100', 'v100', 'p_roads_1000', 's_roads_1700', 's_roads_3000', 'tropomi', 'pod_den_1100', 'Z_r']
# Continous variables: ['mean_no2' 'sp' 'swvl1' 't2m' 'tp' 'u10' 'v10' 'blh' 'u100' 'v100'
#  'p_roads_1000' 's_roads_1700' 's_roads_3000' 'tropomi' 'pod_den_1100'
#  'Z_r']
# <AxesSubplot:xlabel='std_val', ylabel='key'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Make a XGBoost DMatrix object
ytr = in_data['mean_no2'].values # define y variable
xtr = in_data.drop('mean_no2', axis=1) # define x variables
xgdata = xgb.DMatrix(xtr, ytr, missing=np.NaN) # y values are the 'labels' of a DMatrix

# %% [markdown]
# ### Set up training/test data and build optimal model parameters using GridSearchCV

# %%
# split data into train and test
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(xtr,ytr,test_size = 0.10, random_state = 101)

# %%
# set up parameter grid and interate over XGBoost model pareter sets
from sklearn.model_selection import GridSearchCV
gamme_range = list(np.arange(0, 1, 0.5))
eta_range = list(np.arange(0.01, 0.3, 0.05))
lambda_range = list(np.arange(0.6, 1.4, 0.2))
max_depth_range = list(np.arange(5, 7 , 1))
colsample_range = list(np.arange(0.5, 1, 0.25))

param_grid = {'gamma': gamme_range, 'eta' : eta_range , 'reg_lambda' : lambda_range, 'colsample_bytree' : colsample_range, 
              'max_depth' : max_depth_range, 'booster' : ['gbtree']}

# this is the scikit-learn XGBoost interface, which allows sklearn functions like .fit() to be used
xgb_model = xgb.XGBRegressor('reg:squarederror')
xgb_model.fit(X_train, y_train) 

# clf stores
xgb_iters = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2', verbose=1, refit=True, return_train_score=True)
xgb_iters.fit(X_train, y_train)
print('Best parameter set: %s' % xgb_iters.best_params_)
# Out:
# C:\Users\xrnogueira\Anaconda3\envs\cartography\lib\site-packages\xgboost\core.py:430: FutureWarning: Pass `objective` as keyword args.  Passing these as positional arguments will be considered as error in future releases.
#   warnings.warn(
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# Best parameter set: {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eta': 0.01, 'gamma': 0.5, 'max_depth': 5, 'reg_lambda': 1.0}

# %% [markdown]
# ### Make predictions and assess feature importance

# %%
# print best parameter after tuning 
# %matplotlib widget

model = xgb_iters
grid_predictions = model.predict(X_test) 

# Calculate the point density
xy = np.vstack([grid_predictions,y_test])
z = gaussian_kde(xy)(xy)

fig, ax = plt.subplots()
ax.scatter(grid_predictions, y_test, c=z, s=20)
plt.show()

#plt.scatter(grid_predictions, y_test)
plt.title('XGBoost - Inputs: Month, weekend, monthly mean tropomi NO2')
plt.plot(np.arange(0, 60, 0.1), np.arange(0, 60, 0.1), c='red')
plt.xlim(0, np.max(grid_predictions))
plt.ylim(0, np.max(y_test))
plt.xlabel('Predicted NO2 concentration')
plt.ylabel('Actual daily NO2 concentration')
plt.text(0, 22.5, xgb_iters.best_params_, fontsize='x-small')
plt.text(1, 15, 'R2 = %s' % round(r2_score(y_test, grid_predictions), 2), fontsize='large')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(1, 15, 'R2 = 0.37')

# %%
# calculate performance metrics
print('R2 = %s' % r2_score(y_test, grid_predictions))
print('mean_sqrd_error = %s' % mean_squared_error(y_test, grid_predictions))
# Out:
# R2 = 0.3665734291022009
# mean_sqrd_error = 21.17532242443518

# %%
# %matplotlib widget

model = xgb_iters.best_estimator_
x = range(len(model.feature_importances_))
plt.bar(x, model.feature_importances_)
plt.xticks(x, model.get_booster().feature_names, rotation=-45)
plt.subplots_adjust(bottom=0.40)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Explore what is stored in the dataframe, and how we can plot relationships between parameters and scoring

# %% [markdown]
# We are looking to find parameters where the score appears to increase towards valid values not included in our range. If observed, the GridCV ranges can be updated to further tune the model.

# %%
# get dictionary as pandas dataframe and show it
scoring_df = pd.DataFrame.from_dict(xgb_iters.cv_results_)
scoring_df.head(n=20)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.058506      0.005731         0.002599        0.001744
# 1        0.057600      0.001960         0.002400        0.001960
# 2        0.056273      0.002511         0.001999        0.001789
# 3        0.059199      0.002994         0.003200        0.001600
# 4        0.072800      0.002339         0.003200        0.001600
# 5        0.071605      0.001375         0.002199        0.001833
# 6        0.071863      0.001609         0.001999        0.001789
# 7        0.072406      0.000814         0.002400        0.001960
# 8        0.075028      0.034293         0.003200        0.001600
# 9        0.054773      0.001005         0.002199        0.001833
# 10       0.055572      0.003052         0.001600        0.001960
# 11       0.056409      0.000818         0.002400        0.001960
# 12       0.064999      0.001549         0.002400        0.001960
# 13       0.069405      0.001749         0.002400        0.001960
# 14       0.070602      0.003325         0.001999        0.001789
# 15       0.069408      0.002338         0.002998        0.001549
# 16       0.056409      0.000819         0.003201        0.001600
# 17       0.057208      0.001928         0.002199        0.001833
# 18       0.057406      0.001750         0.001600        0.001960
# 19       0.057455      0.001785         0.003799        0.000404
#
#    param_booster param_colsample_bytree param_eta param_gamma param_max_depth  \
# 0         gbtree                    0.5      0.01         0.0               5
# 1         gbtree                    0.5      0.01         0.0               5
# 2         gbtree                    0.5      0.01         0.0               5
# 3         gbtree                    0.5      0.01         0.0               5
# 4         gbtree                    0.5      0.01         0.0               6
# 5         gbtree                    0.5      0.01         0.0               6
# 6         gbtree                    0.5      0.01         0.0               6
# 7         gbtree                    0.5      0.01         0.0               6
# 8         gbtree                    0.5      0.01         0.5               5
# 9         gbtree                    0.5      0.01         0.5               5
# 10        gbtree                    0.5      0.01         0.5               5
# 11        gbtree                    0.5      0.01         0.5               5
# 12        gbtree                    0.5      0.01         0.5               6
# 13        gbtree                    0.5      0.01         0.5               6
# 14        gbtree                    0.5      0.01         0.5               6
# 15        gbtree                    0.5      0.01         0.5               6
# 16        gbtree                    0.5      0.06         0.0               5
# 17        gbtree                    0.5      0.06         0.0               5
# 18        gbtree                    0.5      0.06         0.0               5
# 19        gbtree                    0.5      0.06         0.0               5
#
#    param_reg_lambda  ... mean_test_score  std_test_score  rank_test_score  \
# 0               0.6  ...        0.485004        0.133677               97
# 1               0.8  ...        0.512907        0.118471               19
# 2               1.0  ...        0.513562        0.109243               13
# 3               1.2  ...        0.496835        0.137816               61
# 4               0.6  ...        0.475682        0.087649              145
# 5               0.8  ...        0.477399        0.123631              127
# 6               1.0  ...        0.481873        0.102321              115
# 7               1.2  ...        0.484187        0.115967              103
# 8               0.6  ...        0.497668        0.130041               55
# 9               0.8  ...        0.507077        0.117015               31
# 10              1.0  ...        0.523612        0.120768                1
# 11              1.2  ...        0.515057        0.134505                7
# 12              0.6  ...        0.473634        0.111537              151
# 13              0.8  ...        0.461622        0.118976              175
# 14              1.0  ...        0.486554        0.098552               91
# 15              1.2  ...        0.490968        0.132571               73
# 16              0.6  ...        0.485004        0.133677               97
# 17              0.8  ...        0.512907        0.118471               19
# 18              1.0  ...        0.513562        0.109243               13
# 19              1.2  ...        0.496835        0.137816               61
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0             0.983064            0.994619            0.999631
# 1             0.982902            0.994584            0.999531
# 2             0.982792            0.994668            0.999540
# 3             0.982683            0.994569            0.999688
# 4             0.983177            0.994748            0.999857
# 5             0.983180            0.994746            0.999850
# 6             0.983165            0.994745            0.999851
# 7             0.983179            0.994746            0.999847
# 8             0.981631            0.992930            0.997784
# 9             0.981386            0.992916            0.997621
# 10            0.981378            0.993032            0.998340
# 11            0.981027            0.992966            0.997702
# 12            0.981864            0.993435            0.998498
# 13            0.981976            0.993513            0.998295
# 14            0.981655            0.993550            0.998380
# 15            0.981556            0.993456            0.998269
# 16            0.983064            0.994619            0.999631
# 17            0.982902            0.994584            0.999531
# 18            0.982792            0.994668            0.999540
# 19            0.982683            0.994569            0.999688
#
#     split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0             0.989103            0.984204          0.990124         0.006269
# 1             0.989119            0.984187          0.990065         0.006273
# 2             0.989068            0.984126          0.990039         0.006326
# 3             0.989119            0.984177          0.990047         0.006371
# 4             0.989232            0.984313          0.990265         0.006306
# 5             0.989232            0.984309          0.990263         0.006304
# 6             0.989224            0.984306          0.990258         0.006308
# 7             0.989229            0.984312          0.990263         0.006303
# 8             0.987126            0.982864          0.988467         0.006110
# 9             0.987694            0.982936          0.988511         0.006081
# 10            0.987433            0.983017          0.988640         0.006312
# 11            0.987319            0.982829          0.988369         0.006228
# 12            0.988034            0.983164          0.988999         0.006258
# 13            0.987962            0.983276          0.989004         0.006164
# 14            0.988102            0.983142          0.988966         0.006289
# 15            0.987627            0.983054          0.988792         0.006296
# 16            0.989103            0.984204          0.990124         0.006269
# 17            0.989119            0.984187          0.990065         0.006273
# 18            0.989068            0.984126          0.990039         0.006326
# 19            0.989119            0.984177          0.990047         0.006371
#
# [20 rows x 26 columns]

# %%
# make a list of hyperparameters to iterate over
hypers = list(param_grid.keys())
print(hypers)

hyp_score_dict = {}
param_cols = []
for param in hypers[:-1]:
    # initalize list to store x axis(range values), y axis (mean score), and error bar (score std) for each hyper parameter
    print('Param: %s' % param)
    v_range = param_grid[param]
    hyp_score_dict[param] = [v_range] 
    
    # get column key for dataframe and add to list
    col_key = 'param_%s' % param
    param_cols.append(col_key)
    
    for v in v_range:
        print('Value: %s' % v)
        s1 = scoring_df.loc[scoring_df[col_key] == v]
        print('# of model runs w/ value: %s' % s1.shape[0])
        s2 = s1.groupby(['param_booster']).mean()
        mean_score = s2['mean_train_score'].to_numpy()[0]
        std_score = s2['std_train_score'].to_numpy()[0]
        print(mean_score)
    print('')
s2.head()

# hm, it appears the averages converge. Not as meaningful as I would have thought...thats data science! Let's look at correlations and/or 3D surfaces?
# Out:
# ['gamma', 'eta', 'reg_lambda', 'colsample_bytree', 'max_depth', 'booster']
# Param: gamma
# Value: 0.0
# # of model runs w/ value: 96
# 0.9901857093599943
# Value: 0.5
# # of model runs w/ value: 96
# 0.9887354543037178
#
# Param: eta
# Value: 0.01
# # of model runs w/ value: 32
# 0.989460581831856
# Value: 0.060000000000000005
# # of model runs w/ value: 32
# 0.989460581831856
# Value: 0.11
# # of model runs w/ value: 32
# 0.989460581831856
# Value: 0.16000000000000003
# # of model runs w/ value: 32
# 0.989460581831856
# Value: 0.21000000000000002
# # of model runs w/ value: 32
# 0.989460581831856
# Value: 0.26
# # of model runs w/ value: 32
# 0.989460581831856
#
# Param: reg_lambda
# Value: 0.6
# # of model runs w/ value: 48
# 0.9894886016516867
# Value: 0.8
# # of model runs w/ value: 48
# 0.989463298088335
# Value: 1.0
# # of model runs w/ value: 48
# 0.9894930060269246
# Value: 1.2000000000000002
# # of model runs w/ value: 48
# 0.9893974215604779
#
# Param: colsample_bytree
# Value: 0.5
# # of model runs w/ value: 96
# 0.9894419848859962
# Value: 0.75
# # of model runs w/ value: 96
# 0.9894791787777159
#
# Param: max_depth
# Value: 5
# # of model runs w/ value: 96
# 0.9893181555989742
# Value: 6
# # of model runs w/ value: 96
# 0.9896030080647379
#                mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# param_booster
# gbtree              0.075764      0.003168         0.002562        0.001165
#
#                split0_test_score  split1_test_score  split2_test_score  \
# param_booster
# gbtree                  0.349447           0.467809           0.622777
#
#                split3_test_score  split4_test_score  mean_test_score  \
# param_booster
# gbtree                  0.599182           0.382929         0.484429
#
#                std_test_score  rank_test_score  split0_train_score  \
# param_booster
# gbtree               0.112675           106.75            0.982471
#
#                split1_train_score  split2_train_score  split3_train_score  \
# param_booster
# gbtree                   0.994094            0.999135            0.988571
#
#                split4_train_score  mean_train_score  std_train_score
# param_booster
# gbtree                   0.983744          0.989603         0.006282

# %%
# look at correlations
scoring_simple_df = scoring_df[param_cols]

for name in param_cols:
    print(name)
    # %matplotlib widget
    ax = sns.boxenplot(x='param_max_depth', y='mean_train_score', data=scoring_df)
# Out:
# param_gamma
# param_eta
# param_reg_lambda
# param_colsample_bytree
# param_max_depth
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Compare with straight regression

# %%
# remove nan values (incompatible w/ linear regression)
l_in_data = in_data
l_in_data.dropna(inplace=True)

ytrl = l_in_data['mean_no2'].values # define y variable
xtrl = l_in_data.drop('mean_no2', axis=1) 
X_train_l, X_test_l, y_train_l, y_test_l = train_test_split(xtrl, ytrl ,test_size = 0.15, random_state = 101)

# %%
# set up multiple regression model
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
linear_model.fit(X_train_l, y_train_l)
# Out:
# LinearRegression()

# %%
# plot multiple regression fit
# %matplotlib widget
linear_predictions = linear_model.predict(X_test_l) 

# Calculate the point density
xy = np.vstack([linear_predictions,y_test_l])
z = gaussian_kde(xy)(xy)

plt.title('Linear regression - Inputs: All except elevation + specific humid')
plt.scatter(linear_predictions, y_test_l, c=z)
plt.plot(np.arange(0, 60, 0.1), np.arange(0, 60, 0.1), c='red')
plt.xlim(0, np.max(linear_predictions))
plt.ylim(0, np.max(y_test_l))
plt.xlabel('Predicted NO2 concentration')
plt.ylabel('Actual daily NO2 concentration')
plt.text(1, 15, 'R2 = %s' % round(r2_score(y_test_l, linear_predictions), 2), fontsize='large')
# Out:
# Text(1, 15, 'R2 = 0.21')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
